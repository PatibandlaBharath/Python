# %% [markdown]
# # Set Data Structure

# %% [markdown]
# if we want to represent a group of unique elements then we should use set

# %% [raw]
# 1.Duplicats are not allowed
# 2.Insertion order is not preserve
# 3.we can sort the element
# 4.indexing and slicing are not allowed
# 5.Hetrogeneous objects are allowed

# %%
s={10,30,40,50}
type(s)
# Out:
# set

# %%
s={10,10,10,10}
s
# Out:
# {10}

# %%
list1=[10,20,20,20,30,40,30,30]
s=set(list1)
s
# Out:
# {10, 20, 30, 40}

# %%
five=set(range(5))
five
# Out:
# {0, 1, 2, 3, 4}

# %%
a={}
a
# Out:
# {}

# %%
type(a)
# Out:
# dict

# %%
s=set(a)
type(s)
# Out:
# set

# %% [markdown]
# ## Few functions of set

# %%
s={10,20,30}

# %%
#adding one element
s.add(40)
s
# Out:
# {10, 20, 30, 40}

# %%
#adding multiple numbers
l={50,60,70}
s.update(l)
s
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
#copy

# %%
s={10,40,50,60}
s1=s.copy()

# %%
s1
# Out:
# {10, 40, 50, 60}

# %%
s1.pop()
# Out:
# 40

# %%
s1
# Out:
# {10, 50, 60}

# %%
s1.remove(60)

# %%
s1
# Out:
# {10, 50}

# %%
s1.discard(10)

# %%
s1
# Out:
# {50}

# %%
set1={1,2,3,4,5}
set1.clear()
set1
# Out:
# set()

# %% [markdown]
# # Mathematical operators

# %%
# Union()
s1={10,20,30}
s2={50,60,80,30}
s1.union(s2)
s1|s2
# Out:
# {10, 20, 30, 50, 60, 80}

# %%
s1.intersection(s2)
# Out:
# {30}

# %%
s1&s2
# Out:
# {30}

# %%
#write a program to print different vovels present in the given word
name=set("soumith")
v1={"a","e","i","o","u"}
name&v1
# Out:
# {'i', 'o', 'u'}

# %%
v1={"a","e","i","o","u"}
b=input("Enter a word")
a=set(b)
v1&a
# Out:
# Enter a word Bharath
# {'a'}

# %%
#write a program to remove duplicate from a list
list1=eval(input("enter a list"))
s=set(list1)
s
# Out:
# enter a list 1,2,3,2,1,3,4,6,4,7,5
# {1, 2, 3, 4, 5, 6, 7}
