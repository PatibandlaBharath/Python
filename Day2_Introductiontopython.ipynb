# %% [markdown]
# *Compiler, Interpreter - For running / executing the program
# *CPython

# %% [markdown]
# IDE(Pycharm) - For writing the program

# %% [markdown]
# Code->IDE->Interpret/Compile->Byte_Code->PVM->O/p->IDE

# %% [markdown]
# # Python

# %% [markdown]
# ###### *Python is a general purpose programming language. Ex:App..s,Solving probs,Automate,operate an os*
# ###### *->Highlevel Prog Lang*
# ###### *->Developed by Guido Van Rossam in 1989,He's Working National Institute at Netherlands.*
# ###### *-> Officially launched in feb 20 ,1991*
# ###### *->First prog lang for beginners*
# ###### *->Opensource*

# %%
 # If we print Hello in any lang it'll take 5^ lines of code. python->print("hello")Will do the work

# %%
a=10
b=20
a+b
# Out:
# 30

# %%
print("sum of a & b:",a+b)
# Out:
# sum of a & b: 30

# %% [markdown]
# ### How guido wrote python?

# %% [markdown]
# ###### *->Func Prog features from C*
# ###### *->OOP features from C++*
# ###### *->Scripting Lang from pearl and shell*
# ###### *->Modular prog from modula-3*
# ###### *->Most of the syntax from C & ABC*

# %% [markdown]
# ### Features of Python

# %% [markdown]
# ###### *->Simple & easy*
# ###### *->Freeware & opensource*
# ###### *->Highlevel prog lang*
# ###### *->Platform independent*
# ###### *->Portable*
# ###### *->Dynamically Typed Lang*
# ###### *->Procedure Oriented(c) & Object Oriented(java & c++)*
# ###### *->Interpreted Lang*
# ###### *->Extensible Lang(with python you can use other prog langs as well)*
# ###### *->Embedded*
# ###### *->Has Extensive Lib*

# %% [markdown]
# ### Flavours of Python

# %% [markdown]
# ###### ->*C+Python->Cpython*
# ###### ->*C+Python->Cython*
# ###### ->*Java+Python->Jython*
# ###### ->*Pyhton+Python->PyPython*
# ###### ->*Anaconda+Python->AnacondaPython*

# %% [markdown]
# ### Versions of Python

# %%
# Python 1.0 -> Jan 1994
# Python 2.0 -> Oct 2000
# Python 3.0 -> Dec 2008
