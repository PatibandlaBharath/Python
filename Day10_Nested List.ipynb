# %% [markdown]
# # Nested List

# %% [markdown]
# it means list within the list

# %%
n=[10,20,[30,40]]
n[2]
# Out:
# [30, 40]

# %%
n[1]
# Out:
# 20

# %% [markdown]
# ## Nested list Vs Matrix

# %%
n=[[10,20,30],[40,50,60],[70,80,90]]
print(n)
# Out:
# [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
for i in n:
    print(i)
# Out:
# [10, 20, 30]
# [40, 50, 60]
# [70, 80, 90]
