# %% [markdown]
# # String Data Structure

# %% [raw]
# --character char(python2)
# --string str(python3)

# %%
name="raj"

# %%
name='ram'

# %%
# multilinear literals
name=''' raj
kumar'''

# %% [markdown]
# 1.***How to access characters of a string***

# %% [raw]
# 1.By using index
# 2.By using slicing operator

# %% [markdown]
# **By using index**

# %%
name="Ravi"

# %% [markdown]
# index number feed to[].

# %%
name[0]
# Out:
# 'R'

# %%
name[1]
# Out:
# 'a'

# %%
name[3]
# Out:
# 'i'

# %%
name="soumith"

# %%
name[1]
# Out:
# 'o'

# %%
name[-1]
# Out:
# 'h'

# %%
name[-3]
# Out:
# 'i'

# %% [markdown]
# **By suing slice operator**

# %% [markdown]
# name_of_variable[start:stop:step]

# %%
s="Learning python is very very easy!"

# %%
s[0]
# Out:
# 'L'

# %%
s[0:8:2]
# Out:
# 'Lann'

# %%
s[::-1]
# Out:
# '!ysae yrev yrev si nohtyp gninraeL'

# %% [markdown]
# # Mathmetical operators on str

# %% [raw]
# + operator for concatanation
# * operator for repetation

# %%
print(name+name)
# Out:
# soumithsoumith

# %%
print(name*2)
# Out:
# soumithsoumith

# %% [markdown]
# # Functions in string

# %% [markdown]
# len( )->The number of character present in the string

# %%
s="Ramraj"

# %%
len(s)
# Out:
# 6

# %% [markdown]
# # Checking membership

# %% [markdown]
# we can check the characters are present in string

# %%
s="durga"

# %%
"d" in s
# Out:
# True

# %%
"e" not in s
# Out:
# True

# %%
s=input("Enter the string")
subs=input("enter another string")
if subs in s:
    print(subs,":is found in",s)
else:
    print(subs,":is found in",s)
# Out:
# Enter the string Membership
# enter another string member
# member :is found in Membership

# %% [markdown]
# # Comparing the string

# %%
s1=input("Enter first string")
s2=input("Enter second string")
if s1==s2:
    print("Both strings are equal")
elif s1>s2:
    print("First is greater than second")
else:
    print("Second is greater than first")
# Out:
# Enter first string 1
# Enter second string dd
# Second is greater than first

# %% [markdown]
# # Removing spaces from the strings

# %% [raw]
# there are 3 methods to remove space
# 1.rstrip()-->remove space right handside
# 2.lstrip()-->remove space left handside
# 3.strip()-->remove space from both sides

# %%
city=input("Enter your city name")
scity=city.strip()
if scity=="Hyderabad":
    print("Hello Hyderabadi...Addab")
elif scity=="Chennai":
    print("Hello Madrasi...Vanakkam")
elif scity=="Karnataka":
    print("Hello...Namasthey")
else:
    print("valid city")
# Out:
# Enter your city name Chennai
# Hello Madrasi...Vanakkam

# %% [markdown]
# # Finding substring

# %% [raw]
# we can find out based on direction
# 1.Forward direction
# find()-->Return first ocurance of substring
# index()-->return the substring
# 2.Backward direction
# rfind()
# rindex()

# %% [markdown]
# ## find()

# %%
s="Machine learning is learning machine"
s.find("machine")
# Out:
# 29

# %%
s.find("a",3,15)
# Out:
# 10

# %% [markdown]
# ## index()

# %%
s.index("r",20,40)
# Out:
# 23

# %%
s.rfind("e")
# Out:
# 35

# %%
s.rindex("i")
# Out:
# 33

# %% [markdown]
# # Count function

# %%
#count('a')
s="ababcdgafyusgafegufhipry8whirewfjh"
s.count("b")
# Out:
# 2

# %% [markdown]
# # Replacing the string with another string

# %% [markdown]
# variable.replace(oldstring.newstring)

# %%
s="Learning python is very hard"
s1=s.replace("hard","easy")

# %%
s1
# Out:
# 'Learning python is very easy'

# %% [markdown]
# # Spilitting the string

# %%
#variable.split(seperator)

# %%
t="Tata Consulting"
t.split("ta")
# Out:
# ['Ta', ' Consulting']

# %%
s="Learning python is very hard"
l=s.split()
for x in l:
    print(x)
# Out:
# Learning
# python
# is
# very
# hard

# %%
d="20-2-2026"
today=d.split("-")
for x in today:
    print(x)
# Out:
# 20
# 2
# 2026

# %% [markdown]
# # Joining the string

# %% [markdown]
# seperator.join(group of strings)

# %%
t=("ram","raj","ravi")
s=''.join(t)
s
# Out:
# 'ramrajravi'
