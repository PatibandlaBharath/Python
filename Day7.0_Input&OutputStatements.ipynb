# %% [markdown]
# # Input Statements

# %% [markdown]
# There are two methods to take input:
# 1. ***raw_input()*** *->python2*
# 2. ***input()*** *->python3*

# %% [markdown]
# ### input()

# %% [markdown]
# *Read the data directly from the keyboard.*

# %%
x=input("Enter x value")
# Out:
# Enter x value 10

# %%
type(x)
# Out:
# str

# %% [markdown]
# *Note ->If we write only input, so by default it will take as str*

# %%
a=input("enter name")
print(a)
# Out:
# enter name xander
# xander

# %%
b=input("Enter a number")
c=int(b)
print(c)
type(c)
# Out:
# Enter a number 12
# 12
# int

# %%
type(b)
# Out:
# str

# %%
d=int(input("enter a number"))
type(d)
# Out:
# enter a number 123
# int

# %%
e=float(input("Enter number"))
type(e)
# Out:
# Enter number 12.423
# float

# %%
# write a program to do sum of 2 i/p values
a=int(input("enter a value"))
b=int(input("enter b value"))
print("Sum:",a+b)
# Out:
# enter a value 2
# enter b value 5
# Sum: 7

# %% [markdown]
# #### How to take multiple i/p at a time

# %%
# split() ->splitting the vals.It'll take space as a seperator by default.
a,b=[int(x) for x in input("Enter two values:").split()]
print("product:",a*b)
# Out:
# Enter two values: 2 4
# product: 8

# %%
a,b,c=[float(x) for x in input("Enter three values:").split(",")]
print("sum of three:",a+b+c)
# Out:
# Enter three values: 2.3,43.2,56.4
# sum of three: 101.9

# %% [markdown]
# ### eval()

# %% [markdown]
# *It'll take a string and evaluate the result*

# %%
x=eval("13+23*263/2")
x
# Out:
# 3037.5

# %%
# taking expression as i/p
x=eval(input("Enter expression"))
x
# Out:
# Enter expression 23/2+43*2/4
# 33.0

# %%
# takin' list as i/p
l=eval(input("Enter a list"))
type(l)
# Out:
# Enter a list 2,4,67,8
# tuple

# %% [markdown]
# # Output Statements

# %%
a,b,c,d=41,56,78,8
print(a,b,c,d,sep=",")
# Out:
# 41,56,78,8

# %% [markdown]
# ### formated string

# %%
name="Remington"
salary=250000
friend="kimberly"
print("hello {0} your salary is {1} and friend is {2}".format(name,salary,friend))
print("hello {x} your salary is {y} and friend is {z}".format(x=name,y=salary,z=friend))
# Out:
# hello Remington your salary is 250000 and friend is kimberly
# hello Remington your salary is 250000 and friend is kimberly
