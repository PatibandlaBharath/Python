# %% [markdown]
# # Tuple

# %% [raw]
# Tuple exactly same as list except that is immutable
# once we create we can't modify

# %% [raw]
# 1.Insertion order is preserve
# 2.Duplicates are allowed
# 3.Hetrogeneous object are allowed
# 4.we use ( ) to store element,sep by ","

# %%
t=10,20,30,40
t
# Out:
# (10, 20, 30, 40)

# %%
type(t)
# Out:
# tuple

# %%
t=()
t
# Out:
# ()

# %%
t=(12)
type(t)
# Out:
# int

# %%
t=(22,)
type(t)
# Out:
# tuple

# %%
tu=("sunny","bunny","funny")
type(tu)
# Out:
# tuple

# %%
list1=["sunny","bunny","funny"]
type(list1)
# Out:
# list

# %%
t=tuple(list1)
type(t)
# Out:
# tuple

# %%
t=tuple(range(2,30,3))
t
# Out:
# (2, 5, 8, 11, 14, 17, 20, 23, 26, 29)

# %% [raw]
# #How to access element of tuple either indexing or slice

# %% [markdown]
# ## By Index

# %%
t=10,20,30,40
t
# Out:
# (10, 20, 30, 40)

# %%
t[0]
# Out:
# 10

# %%
t[1]
# Out:
# 20

# %% [markdown]
# ## By using slice operator

# %%
t=10,20,30,40,50,60
t[2:5]
# Out:
# (30, 40, 50)

# %%
t[0:8:2]
# Out:
# (10, 30, 50)

# %% [markdown]
# ## Mathematical operators on tuple

# %%
t1=10,30,50
t2=20,40,60
print(t1+t2)
# Out:
# (10, 30, 50, 20, 40, 60)

# %%
t3=t1*2
t3
# Out:
# (10, 30, 50, 10, 30, 50)

# %% [markdown]
# ### Few functions in tuple

# %%
#len()
tu=10,30,4,60,50,4,47,45,23,10,30
len(tu)
# Out:
# 11

# %%
#count
tu.count(4)
# Out:
# 2

# %%
tu.index(60)
# Out:
# 3

# %%
#sorted()
t=1,4,6,2,3,8,6,9,7
t_sorted=sorted(t)
t_sorted
# Out:
# [1, 2, 3, 4, 6, 6, 7, 8, 9]

# %%
t
# Out:
# (1, 4, 6, 2, 3, 8, 6, 9, 7)

# %%
tu="a","d","c","f","b"
tu_sorted=sorted(tu)
tu_sorted
# Out:
# ['a', 'b', 'c', 'd', 'f']

# %%
#min() an max()
t_sorted
# Out:
# [1, 2, 3, 4, 6, 6, 7, 8, 9]

# %%
min(t_sorted)
# Out:
# 1

# %%
max(t_sorted)
# Out:
# 9

# %%
#cmp()->compaare does not work in python3 
#we can use bool or operaators like >,<,==
t1=10,20,30
t2=40,50,60
t3=10,20,30

# %%
t1==t3
# Out:
# True

# %%
t2>t1
# Out:
# True

# %% [markdown]
# ## Tuple packing and unpacking

# %%
#packing
a,b,c,d=10,40,60,70
t=a,b,c,d
t
# Out:
# (10, 40, 60, 70)

# %%
type(t)
# Out:
# tuple

# %%
#Unpacking
tu=(2,3,4,5,6,7)
a,b,c,d,e,f=tu

# %%
a,b,c,d,e,f
# Out:
# (2, 3, 4, 5, 6, 7)

# %% [markdown]
# ### Difference b/w list vs tuple

# %% [raw]
# 1.list is mutable and tuple is immutable
# 2.[] / ()
# 3.sort and sorted / sorted only
# 4.Growble / read only mode(list)
