# %% [markdown]
# # Operators

# %% [raw]
# Operators are symbols that perform some operations.
# There are many types of operators in python.
#
# 1. Arthimetic Operator
# 2. Relational Operator / Comparison Operator
# 3. Logical Operator
# 4. Bitwise Operator
# 5. Assignment Operator
# 6. Special Operator

# %% [markdown]
# **1.Arthimetic operator**

# %% [raw]
# Addition(+)
# Substraction(-)
# Multiplication(*)
# division(/)
# Modulo(%)
# Floor division(//)
# ** for power/exonentials

# %%
a=5
b=4

# %%
print("Addition",a+b)
print("Substraction",a-b)
print("Multiplication",a*b)
print("division",a/b)
print("Modulo division",a%b)
print("Floor division",a//b)
print("power",a**b)
# Out:
# Addition 9
# Substraction 1
# Multiplication 20
# division 1.25
# Modulo division 1
# Floor division 1
# power 625

# %%
#code for finding out even or odd.
n=13
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
n=14
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %% [markdown]
# **2.Relational Operator**

# %% [raw]
# >,<,>=,<=

# %%
a=50
b=25
print("a > b is",a>b)
print("a < b is",a<b)
print("a >= b is",a>=b)
print("a <= b is",a<=b)
# Out:
# a > b is True
# a < b is False
# a >= b is True
# a <= b is False

# %% [markdown]
# **Equal Operator**

# %% [raw]
# ==,!=

# %%
10==10
# Out:
# True

# %%
10==20
# Out:
# False

# %%
10!=20
# Out:
# True

# %%
"ram"=="ram"
# Out:
# True

# %% [markdown]
# **3.Logical Operator**

# %% [raw]
# and , or , not
# and=if both arguments are true they only result is True
# or=if atleast one argument is True then result is True
# not=not True meaning false, not false means True

# %%
10 and 20
# Out:
# 20

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [raw]
# x and y
# if x is evaluates to False return x otherwise y.

# %%
0 and 20
# Out:
# 0

# %% [raw]
# x or y
# if x is evaluates to True return x otherwise y.

# %%
10 or 20
# Out:
# 10

# %%
0 or 20
# Out:
# 20

# %% [markdown]
# **4. Bitwise Operator**

# %% [raw]
# This operator can be used with integer or bool.
# &,|,^,<<,>>

# %% [markdown]
# #### Conditions

# %% [raw]
# &-> if both are 1 only result 1 otherwise result s o.

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(5)
# Out:
# '0b101'

# %%
print(4&5)
# Out:
# 4

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(25)
# Out:
# '0b11001'

# %% [raw]
# |-> if atleast one bit is 1 then result 1 other 0.

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(15)
# Out:
# '0b1111'

# %%
print(10|15)
# Out:
# 15

# %% [raw]
# ^-> if bits are dfferent then result is 1.otherwise o.

# %%
print(10^15)
# Out:
# 5

# %% [raw]
# 1010
# 1111
# _____
# 0101

# %%
0b0101
# Out:
# 5

# %% [raw]
# >>:- Bitwise Right shift operator

# %%
print(10>>2)
# Out:
# 2

# %%
bin(10)
# Out:
# '0b1010'

# %% [raw]
# <<:-Bitwise left shift operator

# %%
print(10<<2)
# Out:
# 40

# %%
bin(40)
# Out:
# '0b101000'
