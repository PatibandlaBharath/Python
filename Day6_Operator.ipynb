# %% [markdown]
# **5.Assignment Operaator**

# %% [markdown]
# We can use assignment operator to assign a value to a variable

# %%
a=10
#a carries the value 10

# %%
#Now we can combine assignment operator with some other operator
#to compound assignment

# %%
a+=10

# %%
a
# Out:
# 20

# %%
x=20
x+=20
x
# Out:
# 40

# %% [markdown]
# **6.Ternary Operator**

# %% [raw]
# x=first value if condition else second value
# if condition is True then first value will be consider else second value.

# %%
a,b=10,20
x=30 if a>b else 40
x
# Out:
# 40

# %%
a,b=10,20
x=30 if a<b else 40
x
# Out:
# 30

# %%
#taking input from keyboard and print minimum value

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
min=a if a<b else b
min
# Out:
# Enter the first number 50
# Enter the second number 100
# 50

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
max=a if a>b else b
max
# Out:
# Enter the first number 40
# Enter the second number 90
# 90

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
min=a if a>b else b
min
# Out:
# Enter the first number 60
# Enter the second number 60
# 60

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the first number"))
c=int(input("Enter the Third number"))
max=a if a>b<c else c
min=b if a<b>c else b
min , max
# Out:
# Enter the first number 30
# Enter the first number 60
# Enter the Third number 80
# (60, 80)

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the first number"))
c=int(input("Enter the Third number"))
max=a if a>b<c else c  
min=b if a>b>c else b 
min , max
# Out:
# Enter the first number 70
# Enter the first number 90
# Enter the Third number 100
# (90, 100)

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the first number"))
c=int(input("Enter the Third number"))
x=int(input("Enter the fourth number"))
y=int(input("Enter the fifth number"))
z=int(input("Enter the six number"))
max=a if a>=b<c and x>y<=z else y 
min=b if a>b>=c and x>y>=z else x 
min , max
# Out:
# Enter the first number 70
# Enter the first number 90
# Enter the Third number 20
# Enter the fourth number 100
# Enter the fifth number 50
# Enter the six number 30
# (100, 50)

# %% [markdown]
# **6.Special opertor**

# %% [markdown]
# There are two special operator in python

# %% [raw]
# 1.identity Opeator
# 2.Membership Operator

# %% [raw]
# **Identity Operator**
# we can identify operators for address comparision
# two identity operator are there
# is
# is not

# %%
a=10
b=20

# %%
a is b
# Out:
# False

# %%
a=10
b=10
a is b
# Out:
# True

# %%
id(a)
# Out:
# 140704057046216

# %%
id(b)
# Out:
# 140704057046216

# %%
a=5+8j
id(a)
# Out:
# 1397162346320

# %%
b=5+8j
id(b)
# Out:
# 1397162347536

# %%
a is b
# Out:
# False

# %%
a="ram"
b="ram"
a is b
# Out:
# True

# %%
list1=["one","two","three"]
list2=["one","two","three"]
list1 is list2
# Out:
# False

# %%
id(list1)
# Out:
# 1397162534080

# %%
id(list2)
# Out:
# 1397162576768

# %% [raw]
# **Membership Operator**
# in => Return true if the given object present in the specified collection
# not in => Return true if the given object not present in the specified collection

# %%
x="Learning python is very easy !!"
'L' in x
# Out:
# True

# %%
'p' in x
# Out:
# True

# %%
'z' in x
# Out:
# False

# %%
'd' not in x
# Out:
# True

# %%
'e' not in x
# Out:
# False

# %%
list1=["ram","raj","ravi","raja"]
'ram' in list1
# Out:
# True

# %% [markdown]
# # Operator Precedence

# %% [markdown]
# If multiple operator present then which operator will be
# evaluated first that will decide by Operator precedence.

# %%
3+5*4
# Out:
# 23

# %%
66+879-83/23
# Out:
# 941.3913043478261

# %% [raw]
# ()       :- paranthesis
# **       :- Exponential
# ~,       :-Bitwise
# *,/,%,//
# +,-
# <<,>>
# & bitwise end
