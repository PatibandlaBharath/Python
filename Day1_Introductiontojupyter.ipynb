# %%
# Types of Cell
# 1.Code--Write the code
# 2.Markdown--Headings with format
# 3.RAW--Raw text or data without format

# %%
# sel ctrl+/ or use # --comments
# shift enter--run and come into new cell
# ctrl enter--only running cell and not move into nxt cell

# %%
# esc+a -upper cell
# esc+b -lower cell
# esc+dd - removing or deleting cell

# %%
print(9+9)
# Out:
# 18

# %%
print("hello--example of code--esc+y")
# Out:
# hello--example of code--esc+y

# %% [markdown]
# Example of markdown--esc+m

# %% [raw]
# example of raw--esc+r

# %%
# esc+M--markdown
# esc+y--code
# esc+r--raw

# %%
"Formating"
# Out:
# 'Formating'

# %% [markdown]
# ### How to give Heading for markdown

# %% [raw]
# using # --- the number of # increase(upto 6) : Decrease in heading size

# %% [markdown]
# # Heading1
# ## Heading2
# ### Heading3
# #### Heading4
# ##### Heading5
# ###### Heading6

# %% [raw]
# using esc+1 and so on.. ---- shoter the number larger the heading size

# %% [markdown]
# # Heading1

# %% [markdown]
# ## How to write in bold,italic,bold+italic format

# %% [raw]
# using **abc**-- for bold
# using *abc*--for italic
# using ***abc***-for both

# %% [markdown]
# **Hello**

# %% [markdown]
# *hello*

# %% [markdown]
# ***hello***

# %% [markdown]
# ## Combining heading size with b,i,b+i formats

# %% [raw]
# using # ***abc***-- we can icrease no of #

# %% [markdown]
# #### ***hello***

# %% [markdown]
# ### Lists

# %% [raw]
# using : - abc (unordered)
# using : 1. abc (ordered)

# %% [markdown]
# - First
# - second
# - third

# %% [markdown]
# 1. first
# 2. second
# 3. third
