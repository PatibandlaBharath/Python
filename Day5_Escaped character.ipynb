# %% [raw]
# In string literals we can use escape character to associte a special meaning

# %%
# \n for new line 
da="Data\nAnalytics"
print(da)
# Out:
# Data
# Analytics

# %%
# \t for on tab distance
ai="Artificial\tIntelligence"
print(ai)
# Out:
# Artificial	Intelligence

# %%
# \b for back space
gd="Graphic\bDesign"
print(gd)
# Out:
# GraphiDesign

# %%
# \v for vertical tab
da="Data\vAnalytics"
print(da)
# Out:
# DataAnalytics

# %%
da="Data\rAnalytics"
print(da)
# Out:
# Analytics

# %%
da="Data\fAnalytics"
print(da)
# Out:
# DataAnalytics

# %%
da="Data\'Analytics"
print(da)
# Out:
# Data'Analytics

# %%
da="Data\\Analytics"
print(da)
# Out:
# Data\Analytics
